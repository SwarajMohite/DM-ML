# %% [markdown]
# <a href="https://colab.research.google.com/github/SwarajMohite/DM-ML/blob/main/KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x = [3,2,1,7,8,7,5]
y = [12,14,54,23,87,54,9]
classes = [0,0,0,1,1,1,1]

plt.scatter(x,y,c=classes)

plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier

data = list(zip(x,y))

knn = KNeighborsClassifier()

knn.fit(data,classes)
# Out:
# KNeighborsClassifier()

# %%
new_x = 5
new_y = 8

new_data = [(new_x, new_y)]

prediction = knn.predict(new_data)

plt.scatter(x+[new_x], y+[new_y],c=classes + [prediction[0]])

plt.show()
print(f"The predicted class is : {prediction[0]}")
# Out:
# The predicted class is : 1

# %%
knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(data, classes)

prediction = knn.predict(new_data)

plt.scatter(x + [new_x], y + [new_y], c=classes + [prediction[0]])
plt.show()

print(f"new point, class: {prediction[0]}")
# Out:
# new point, class: 1
